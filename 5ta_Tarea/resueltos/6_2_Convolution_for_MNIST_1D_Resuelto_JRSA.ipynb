# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-f3dbqd19
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-f3dbqd19
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.34.2)
# Requirement already satisfied: numpy in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.4.6)
# Requirement already satisfied: matplotlib in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.9)
# Requirement already satisfied: scipy in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.18.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.20)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.8.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /home/zanz19/.venv/jupyter/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10

# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
# ESCRIBE TU CÓDIGO AQUÍ (esto es una fully connected network de ejemplo, reemplázala
# por la red convolucional que se pide en el enunciado)
model = nn.Sequential(
nn.Linear(D_i, D_i),
nn.ReLU(),
nn.Linear(D_i, D_o))

# %%
# 🟩 RESPUESTA (JRSA)
D_i = 40
D_o = 10

# Tres capas convolucionales 1D con stride 2 y padding "valid" (sin relleno),
# reduciendo la longitud de la secuencia en cada capa: 40 -> 19 -> 9 -> 4
# (comprobado: floor((L_in - kernel)/stride) + 1 para kernel=3, stride=2)
model = nn.Sequential(
nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60, 10))

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.989668, training error 79.50, validation loss 1.998388, validation error 77.70
# Epoch     1, training loss 1.583824, training error 63.15, validation loss 1.621746, validation error 65.10
# Epoch     2, training loss 1.392415, training error 56.28, validation loss 1.398494, validation error 57.20
# Epoch     3, training loss 1.276063, training error 52.55, validation loss 1.308712, validation error 56.40
# Epoch     4, training loss 1.174235, training error 47.97, validation loss 1.209314, validation error 51.20
# Epoch     5, training loss 1.146148, training error 46.80, validation loss 1.182780, validation error 49.00
# Epoch     6, training loss 1.205195, training error 48.70, validation loss 1.231884, validation error 51.10
# Epoch     7, training loss 0.989935, training error 39.92, validation loss 1.023964, validation error 43.10
# Epoch     8, training loss 0.960911, training error 38.05, validation loss 0.991921, validation error 40.70
# Epoch     9, training loss 0.851691, training error 33.28, validation loss 0.877050, validation error 36.50
# Epoch    10, training loss 0.819941, training error 32.22, validation loss 0.849505, validation error 33.80
# Epoch    11, training loss 0.735915, training error 28.85, validation loss 0.778208, validation error 31.40
# Epoch    12, training loss 0.713690, training error 28.43, validation loss 0.774469, validation error 31.00
# Epoch    13, training loss 0.622441, training error 24.62, validation loss 0.679404, validation error 27.70
# Epoch    14, training loss 0.614185, training error 24.05, validation loss 0.695464, validation error 26.20
# Epoch    15, training loss 0.528188, training error 20.22, validation loss 0.623120, validation error 23.40
# Epoch    16, training loss 0.484928, training error 17.40, validation loss 0.592967, validation error 22.30
# Epoch    17, training loss 0.535300, training error 20.70, validation loss 0.618680, validation error 23.40
# Epoch    18, training loss 0.363677, training error 13.93, validation loss 0.466061, validation error 16.80
# Epoch    19, training loss 0.392542, training error 14.45, validation loss 0.508160, validation error 20.40
# Epoch    20, training loss 0.303407, training error 10.90, validation loss 0.404612, validation error 14.00
# Epoch    21, training loss 0.265885, training error 9.62, validation loss 0.405500, validation error 14.70
# Epoch    22, training loss 0.252808, training error 9.32, validation loss 0.402839, validation error 13.90
# Epoch    23, training loss 0.248486, training error 9.20, validation loss 0.406407, validation error 15.30
# Epoch    24, training loss 0.227697, training error 7.80, validation loss 0.376541, validation error 14.50
# Epoch    25, training loss 0.203458, training error 7.03, validation loss 0.366661, validation error 13.10
# Epoch    26, training loss 0.186352, training error 6.40, validation loss 0.350786, validation error 12.00
# Epoch    27, training loss 0.183576, training error 6.30, validation loss 0.361760, validation error 13.40
# Epoch    28, training loss 0.191665, training error 6.95, validation loss 0.373435, validation error 12.60
# Epoch    29, training loss 0.163078, training error 5.57, validation loss 0.335368, validation error 11.30
# Epoch    30, training loss 0.171261, training error 6.28, validation loss 0.373009, validation error 13.40
# Epoch    31, training loss 0.160246, training error 5.82, validation loss 0.362753, validation error 12.50
# Epoch    32, training loss 0.132946, training error 4.30, validation loss 0.329187, validation error 11.30
# Epoch    33, training loss 0.129513, training error 4.43, validation loss 0.349852, validation error 11.10
# Epoch    34, training loss 0.135705, training error 4.88, validation loss 0.351786, validation error 11.80
# Epoch    35, training loss 0.120721, training error 4.05, validation loss 0.349565, validation error 12.00
# Epoch    36, training loss 0.113925, training error 3.65, validation loss 0.341976, validation error 11.70
# Epoch    37, training loss 0.115641, training error 3.97, validation loss 0.354513, validation error 11.10
# Epoch    38, training loss 0.106498, training error 3.40, validation loss 0.371523, validation error 12.20
# Epoch    39, training loss 0.107328, training error 3.55, validation loss 0.351533, validation error 10.80
# Epoch    40, training loss 0.093539, training error 3.05, validation loss 0.323922, validation error 10.60
# Epoch    41, training loss 0.080227, training error 2.45, validation loss 0.329603, validation error 10.30
# Epoch    42, training loss 0.077868, training error 2.12, validation loss 0.330956, validation error 10.20
# Epoch    43, training loss 0.079813, training error 2.53, validation loss 0.353758, validation error 10.30
# Epoch    44, training loss 0.075761, training error 2.32, validation loss 0.337333, validation error 10.10
# Epoch    45, training loss 0.087471, training error 3.10, validation loss 0.348239, validation error 10.90
# Epoch    46, training loss 0.071040, training error 1.95, validation loss 0.342101, validation error 10.50
# Epoch    47, training loss 0.067747, training error 1.97, validation loss 0.347360, validation error 10.20
# Epoch    48, training loss 0.072408, training error 2.12, validation loss 0.358668, validation error 10.90
# Epoch    49, training loss 0.078036, training error 2.60, validation loss 0.357772, validation error 10.40
# Epoch    50, training loss 0.066245, training error 1.80, validation loss 0.364805, validation error 10.70
# Epoch    51, training loss 0.064098, training error 1.80, validation loss 0.338313, validation error 10.30
# Epoch    52, training loss 0.067439, training error 1.82, validation loss 0.370450, validation error 10.80
# Epoch    53, training loss 0.069034, training error 2.10, validation loss 0.357554, validation error 11.10
# Epoch    54, training loss 0.062613, training error 1.70, validation loss 0.363661, validation error 10.50
# Epoch    55, training loss 0.068680, training error 2.28, validation loss 0.366849, validation error 10.70
# Epoch    56, training loss 0.054895, training error 1.30, validation loss 0.353431, validation error 10.30
# Epoch    57, training loss 0.068764, training error 2.10, validation loss 0.386271, validation error 10.60
# Epoch    58, training loss 0.065659, training error 1.90, validation loss 0.370036, validation error 10.00
# Epoch    59, training loss 0.053754, training error 1.40, validation loss 0.379880, validation error 10.80
# Epoch    60, training loss 0.049762, training error 1.10, validation loss 0.375415, validation error 10.70
# Epoch    61, training loss 0.049380, training error 1.15, validation loss 0.374998, validation error 10.40
# Epoch    62, training loss 0.046262, training error 0.93, validation loss 0.365485, validation error 10.50
# Epoch    63, training loss 0.047659, training error 1.00, validation loss 0.379235, validation error 10.70
# Epoch    64, training loss 0.046037, training error 1.03, validation loss 0.366722, validation error 10.20
# Epoch    65, training loss 0.047870, training error 0.95, validation loss 0.381579, validation error 10.80
# Epoch    66, training loss 0.045496, training error 1.00, validation loss 0.373793, validation error 10.80
# Epoch    67, training loss 0.049349, training error 1.25, validation loss 0.373964, validation error 10.20
# Epoch    68, training loss 0.043440, training error 0.82, validation loss 0.381392, validation error 10.60
# Epoch    69, training loss 0.042858, training error 0.82, validation loss 0.374838, validation error 10.50
# Epoch    70, training loss 0.044047, training error 1.00, validation loss 0.370301, validation error 10.20
# Epoch    71, training loss 0.042023, training error 0.82, validation loss 0.377133, validation error 10.50
# Epoch    72, training loss 0.043667, training error 0.95, validation loss 0.377548, validation error 10.00
# Epoch    73, training loss 0.041292, training error 0.90, validation loss 0.378072, validation error 10.20
# Epoch    74, training loss 0.041375, training error 0.82, validation loss 0.390768, validation error 10.60
# Epoch    75, training loss 0.039789, training error 0.72, validation loss 0.387091, validation error 10.40
# Epoch    76, training loss 0.040163, training error 0.78, validation loss 0.375831, validation error 9.90
# Epoch    77, training loss 0.039484, training error 0.75, validation loss 0.381204, validation error 9.90
# Epoch    78, training loss 0.038977, training error 0.70, validation loss 0.374687, validation error 10.10
# Epoch    79, training loss 0.038702, training error 0.75, validation loss 0.388621, validation error 10.60
# Epoch    80, training loss 0.036912, training error 0.53, validation loss 0.386377, validation error 10.30
# Epoch    81, training loss 0.036872, training error 0.57, validation loss 0.387163, validation error 10.20
# Epoch    82, training loss 0.036589, training error 0.68, validation loss 0.388501, validation error 10.40
# Epoch    83, training loss 0.036102, training error 0.57, validation loss 0.387999, validation error 10.20
# Epoch    84, training loss 0.035945, training error 0.50, validation loss 0.385185, validation error 10.20
# Epoch    85, training loss 0.036013, training error 0.62, validation loss 0.386358, validation error 10.10
# Epoch    86, training loss 0.035428, training error 0.50, validation loss 0.388754, validation error 10.40
# Epoch    87, training loss 0.035590, training error 0.47, validation loss 0.389587, validation error 10.10
# Epoch    88, training loss 0.036445, training error 0.65, validation loss 0.394414, validation error 10.30
# Epoch    89, training loss 0.035179, training error 0.47, validation loss 0.388835, validation error 10.00
# Epoch    90, training loss 0.035005, training error 0.57, validation loss 0.391223, validation error 10.10
# Epoch    91, training loss 0.034814, training error 0.50, validation loss 0.389052, validation error 10.30
# Epoch    92, training loss 0.034222, training error 0.50, validation loss 0.392753, validation error 10.20
# Epoch    93, training loss 0.034446, training error 0.53, validation loss 0.400483, validation error 10.30
# Epoch    94, training loss 0.034340, training error 0.50, validation loss 0.397987, validation error 10.10
# Epoch    95, training loss 0.034511, training error 0.47, validation loss 0.394317, validation error 10.10
# Epoch    96, training loss 0.033807, training error 0.45, validation loss 0.392076, validation error 10.30
# Epoch    97, training loss 0.033575, training error 0.40, validation loss 0.392995, validation error 10.10
# Epoch    98, training loss 0.033201, training error 0.47, validation loss 0.396496, validation error 10.20
# Epoch    99, training loss 0.033192, training error 0.43, validation loss 0.395695, validation error 10.00
